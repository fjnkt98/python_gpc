# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.stats import norm

# %%
# Raw data
data_raw = np.loadtxt("lidar_data_20201026.csv", delimiter=',', skiprows=1)

# Extract list of range data from raw data
# and onvert the units of range to meters
data = data_raw.T[1] / 1000

# Check length
len(data)
# Out:
# 6.870899040090344

# %%
mean = 6.870899040090344
std  = 0.016552210800017474

# %%
xs = np.arange(6.5, 7.5, 0.001)
ys = norm.pdf(xs, mean, std)

ys = ys / sum(ys)

plt.plot(xs, ys)
plt.show()
